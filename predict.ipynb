# %%
# ===== CONFIG =====
import os
INPUT_DIR = os.environ.get("ITDA_INPUT_DIR", "./val_images")
OUTPUT_PATH = os.environ.get("ITDA_OUTPUT_PATH", "./submission.csv")
# ==================

# %%
from ocr_pipeline import run_submission

rows = run_submission(INPUT_DIR, OUTPUT_PATH)
print(f"Saved {len(rows)} predictions to {OUTPUT_PATH}")
